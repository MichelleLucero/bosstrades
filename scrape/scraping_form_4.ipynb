# %% [markdown]
# ## Import Libraries

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import time
from datetime import datetime

# %% [markdown]
# ## Scrape links to form 4

# %%
# url = 'https://www.sec.gov/cgi-bin/current?q1=0&q2=0&q3=4'

# page = requests.get(url)
# soup = BeautifulSoup(page.text, 'lxml')
# link_list = []

# for link in soup.find_all('a'):
#     # ensures all links are for form 4
#     if link.text == '4':
#         link_to_save = 'https://www.sec.gov' + link.get('href')
#         link_list.append(link_to_save)
url = "https://www.sec.gov/cgi-bin/current?q1=0&q2=0&q3=4"


page = requests.get(url)    
data = page.text
soup = BeautifulSoup(data, "lxml")
days_url = []
appended_dataframes = []

for link in soup.find_all('a'):
    if 'index' in link.get('href'):
        url_to_save = link.get('href')
        days_url.append(url_to_save)

# %% [markdown]
# ## Scrape form 4 info

# %%
headers = {"user-agent": "Mozilla/5.0"}
# link = requests.get("https://www.sec.gov/Archives/edgar/data/1464274/0000899751-21-000101-index.html", headers=headers)
# pd.read_html(link.text)

# for link in link_list:
#     time.sleep(10)
#     link = requests.get(link, headers=headers)
#     index = pd.read_html(link.text)
#     # print(index)
#     index = index[0]
#     #change the type == 4
#     index = index[(index['Document'].str.contains('.html')) & ( (index['Type'] == 4)| ( (index['Type'] == str(4)))) ]
for item in days_url:
    time.sleep(5)
    index ='https://www.sec.gov'+item
    index = requests.get(index, headers=headers)
    index = pd.read_html(index.text)

    index = index[0]
    #change the type == 4
    index = index[(index['Document'].str.contains('.html')) & ( (index['Type'] == 4)| ( (index['Type'] == str(4)))) ]
  
    try:
        index = index['Document'].iloc[0]
    except:
        index = ''
    url = item.replace('-index.html','')
    url = url.replace('-','')
    url = 'https://www.sec.gov'+  url + '/xslF345X03/' + index
    url = url.replace('html','xml')
    cik_company = item.split('data/')[1].split('/')[0]
    print(url)
    try:
        insider_transactions = pd.read_html(url)
    except:
        insider_transactions = ''
        name = ''
    try:
        name = insider_transactions[3]
        name_person = name[0].iloc[0].split('*')[1].split('(')[0]
    except:
        name_person = ''
    try:
        ticker = name[1].iloc[0].split('[ ')[1].split(']')[0]
    except:
        ticker = ''
    try:
        position = name[2].iloc[0].split('(specify below)')[1]
    except:
        position = ''
    try:
        insider_transactions = insider_transactions[11]
        insider_transactions.reset_index(inplace=True)
        insider_transactions.columns = [['placeholder','Title','Date of Trans','Deemed Execution Day','Transaction Code','empty','Amount','Adq or Disp','Price','Shares Owned after Trans','Direct or Indirect Ownershipt','Nature of Ind Ownershipt']]
        insider_transactions['position'] = position
        insider_transactions['name_person'] = name_person
        insider_transactions['ticker'] = ticker
        appended_dataframes.append(insider_transactions)

    except:
        insider_transactions = ''
  
    print(name_person)
    print(position)
    time.sleep(2)               
   
InsideTransactionsDF = pd.concat(appended_dataframes)
# Out:
# 057/xslF345X03/doc4.xml
# STACK GEOFFREY L
#
# https://www.sec.gov/Archives/edgar/data/96869/000120919121046058/xslF345X03/doc4.xml
#
#
# https://www.sec.gov/Archives/edgar/data/96869/000120919121046060/xslF345X03/doc4.xml
#
#
# https://www.sec.gov/Archives/edgar/data/96869/000120919121046061/xslF345X03/doc4.xml
#
#
# https://www.sec.gov/Archives/edgar/data/96869/000120919121046062/xslF345X03/doc4.xml
#
#
# https://www.sec.gov/Archives/edgar/data
xslF345X03/doc4.xml
#
#
# https://www.sec.gov/Archives/edgar/data/1403752/000089924321027913/xslF345X03/doc4.xml
# Klompas Neil A
#  Chief Financial Officer
# https://www.sec.gov/Archives/edgar/data/1403752/000089924321027914/xslF345X03/doc4.xml
#
#
# https://www.sec.gov/Archives/edgar/data/1403752/000089924321027916/xslF345X03/doc4.xml
#
#
# https://www.sec.gov/Archives/edgar/data/1824920/000119312521210636/xslF345X03/
#
#
# https://www.sec.gov/Archives/edgar/data/1862106/000114036121023808/xslF345X03/form4.xml
#
#
# https://www.sec.gov/Archives/edgar/data/1484769/000149315221016482/xslF345X03/ownership.xml
#
#
# https://www.sec.gov/Archives/edgar/data/1484769/000149315221016484/xslF345X03/ownership.xml
#
#
# https://www.sec.gov/Archives/edgar/data/1386395/000121465921007380/xslF345X03/marketforms-53365.xml
# van Veenendaal Frank

# %%
InsideTransactionsDF.to_csv('InsideTransactionsDF.csv', index=False)

# %%
df = pd.read_csv('InsideTransactionsDF.csv')
df.iloc[11:32,:]
ls = set(df['ticker'])
ls
# Out:
# {'ABOS ',
#  'ADPT ',
#  'AIRI ',
#  'ALTR ',
#  'AMPH ',
#  'ANET ',
#  'ARQT ',
#  'AVID ',
#  'BCML ',
#  'BCYC ',
#  'BGNE ',
#  'BILL ',
#  'BLFS ',
#  'BLI ',
#  'BOH ',
#  'BTRS ',
#  'CCMP ',
#  'CENT ',
#  'CHCO ',
#  'CORR ',
#  'COUP ',
#  'CPK ',
#  'CRCT ',
#  'CYTK ',
#  'CZNC ',
#  'DASH ',
#  'DIOD ',
#  'DNUT ',
#  'DRNA ',
#  'ESPR ',
#  'ETWO ',
#  'EVCM ',
#  'FB ',
#  'FMAO ',
#  'FNWB ',
#  'FORD ',
#  'FSLY ',
#  'FTCV ',
#  'FUBO ',
#  'GDOT ',
#  'GEVO ',
#  'GGGV ',
#  'GO ',
#  'GOOG ',
#  'HCAT ',
#  'HCHC ',
#  'HELE ',
#  'HOG ',
#  'IBKR ',
#  'JWA/JWB ',
#  'KBLB ',
#  'KLIC ',
#  'KSU ',
#  'LAUR ',
#  'LUB ',
#  'MCBS ',
#  'MDB ',
#  'MIME ',
#  'MIND ',
#  'MKC ',
#  'MORN ',
#  'MRNA ',
#  'MTSI ',
#  'N/A ',
#  'NBRV ',
#  'NETE ',
#  'NVCR ',
#  'PAYC ',
#  'PFSW ',
#  'PINS ',
#  'PLL ',
#  'PMVP ',
#  'PRCH ',
#  'PRLD ',
#  'PRTS ',
#  'PSMT ',
#  'QMCO ',
#  'QUOT ',
#  'RARE ',
#  'RDFN ',
#  'RRD ',
#  'RVLV ',
#  'SFIX ',
#  'SHEN ',
#  'SIVB ',
#  'SMAR ',
#  'SNAP ',
#  'SNOW ',
#  'SWCH ',
#  'TOMDF ',
#  'TRC ',
#  'TROW ',
#  'TT ',
#  'TWLO ',
#  'UEC ',
#  'USIO ',
#  'VIR ',
#  'VRNS ',
#  'VRSN ',
#  'VSAT ',
#  'VZ ',
#  'WDC ',
#  'WRAP ',
#  'XMTR ',
#  'ZDGE ',
#  'ZI ',
#  'ZM ',
#  'ZNGA ',
#  'ZNTL ',
#  'ZS ',
#  'ZYME ',
#  'grwc '}
